# %% [raw]
# ---
# description: A type of stochastic neural network that can learn a probability distribution
#   over its set of inputs. Often used as building blocks for deep belief networks.
# output-file: rbm.html
# skip_exec: true
# skip_showdoc: true
# title: RBM - Restricted Boltzmann Machines
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
