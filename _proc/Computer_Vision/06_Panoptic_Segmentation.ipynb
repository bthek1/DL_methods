# %% [raw]
# ---
# description: Combines both semantic and instance segmentation by classifying each
#   pixel into either a semantic class or a unique instance.
# output-file: panoptic_segmentation.html
# skip_exec: true
# skip_showdoc: true
# title: Panoptic Segmentation
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Dataset

# %% [markdown]
# ## Models

# %% [markdown]
# Common Models: Panoptic FPN, UPSNet.

# %% [markdown]
# ## Hyperparameters

# %% [markdown]
# ## Loss Functions
